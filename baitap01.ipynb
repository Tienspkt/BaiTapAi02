# %% [markdown]
# <a href="https://colab.research.google.com/github/Tienspkt/google-colab/blob/main/baitap01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.head(20)
data[data['NOC']== 'BEL']
# Out:
#       Year        City      Sport      Discipline  NOC       Event  \
# 3     1924    Chamonix  Bobsleigh       Bobsleigh  BEL    four-man
# 53    1928  St. Moritz    Skating  Figure skating  BEL  individual
# 191   1948  St. Moritz  Bobsleigh       Bobsleigh  BEL    four-man
# 192   1948  St. Moritz    Skating  Figure skating  BEL       pairs
# 1638  1998      Nagano    Skating   Speed skating  BEL       5000m
#
#      Event gender   Medal
# 3               M  Bronze
# 53              M  Bronze
# 191             M  Silver
# 192             X    Gold
# 1638            M  Bronze

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.head(20)
data[data['NOC']== 'CAN'] #lấy dữ liệu cửa nước canada
# Out:
#       Year         City       Sport       Discipline  NOC            Event  \
# 4     1924     Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# 54    1928   St. Moritz  Ice Hockey       Ice Hockey  CAN       ice hockey
# 92    1932  Lake Placid  Ice Hockey       Ice Hockey  CAN       ice hockey
# 93    1932  Lake Placid     Skating   Figure skating  CAN       individual
# 94    1932  Lake Placid     Skating    Speed skating  CAN           10000m
# ...    ...          ...         ...              ...  ...              ...
# 2105  2006        Turin     Skating    Speed skating  CAN     Team pursuit
# 2106  2006        Turin      Skiing  Cross Country S  CAN     Sprint 1.5km
# 2107  2006        Turin      Skiing  Cross Country S  CAN      Team sprint
# 2108  2006        Turin      Skiing   Freestyle Ski.  CAN           moguls
# 2109  2006        Turin      Skiing        Snowboard  CAN  Snowboard Cross
#
#      Event gender   Medal
# 4               M    Gold
# ...

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data['NOC'].max() #nước có huy chương nhiểu nhất
# Out:
# 'YUG'

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data['NOC'].min() #nước có huy chương nhiểu nhất
# Out:
# 'AUS'

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data[(data['NOC']=='CAN') & (data['Year']==2006)]
# Out:
#       Year   City       Sport       Discipline  NOC            Event  \
# 2086  2006  Turin   Bobsleigh        Bobsleigh  CAN          two-man
# 2087  2006  Turin   Bobsleigh         Skeleton  CAN       individual
# 2088  2006  Turin   Bobsleigh         Skeleton  CAN       individual
# 2089  2006  Turin   Bobsleigh         Skeleton  CAN       individual
# 2090  2006  Turin     Curling          Curling  CAN          curling
# 2091  2006  Turin     Curling          Curling  CAN          curling
# 2092  2006  Turin  Ice Hockey       Ice Hockey  CAN       ice hockey
# 2093  2006  Turin     Skating   Figure skating  CAN       individual
# 2094  2006  Turin     Skating   Short Track S.  CAN      3000m relay
# 2095  2006  Turin     Skating   Short Track S.  CAN      5000m relay
# 2096  2006  Turin     Skating   Short Track S.  CAN             500m
# 2097  2006  Turin     Skating   Short Track S.  CAN             500m
# 2098  2006  Turin     Skating    Speed skating  CAN            1000m
# ...

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data[data['NOC']== 'CAN'] #lấy dữ liệu nước canada
data[(data['NOC']=='CAN')&(data['Medal']=='Gold')] # lấy huy chương vàng của tất cả các năm của nước CANADA
# Out:
#       Year            City       Sport       Discipline  NOC         Event  \
# 4     1924        Chamonix  Ice Hockey       Ice Hockey  CAN    ice hockey
# 54    1928      St. Moritz  Ice Hockey       Ice Hockey  CAN    ice hockey
# 92    1932     Lake Placid  Ice Hockey       Ice Hockey  CAN    ice hockey
# 193   1948      St. Moritz  Ice Hockey       Ice Hockey  CAN    ice hockey
# 194   1948      St. Moritz     Skating   Figure skating  CAN    individual
# 259   1952            Oslo  Ice Hockey       Ice Hockey  CAN    ice hockey
# 398   1960    Squaw Valley     Skating   Figure skating  CAN         pairs
# 399   1960    Squaw Valley      Skiing    Alpine Skiing  CAN        slalom
# 483   1964       Innsbruck   Bobsleigh        Bobsleigh  CAN      four-man
# 586   1968        Grenoble      Skiing    Alpine Skiing  CAN  giant slalom
# 793   1976       Innsbruck      Skiing    Alpine Skiing  CAN  giant slalom
# ...

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data[data['NOC']== 'CAN'] #lấy dữ liệu nước canada
data[(data['NOC']=='CAN')&(data['Year']==2006)&(data['Medal']=='Gold')]#số huy chương vàng nước canada đạt được năm 2006
# Out:
#       Year   City       Sport       Discipline  NOC         Event  \
# 2087  2006  Turin   Bobsleigh         Skeleton  CAN    individual
# 2090  2006  Turin     Curling          Curling  CAN       curling
# 2092  2006  Turin  Ice Hockey       Ice Hockey  CAN    ice hockey
# 2099  2006  Turin     Skating    Speed skating  CAN         1500m
# 2103  2006  Turin     Skating    Speed skating  CAN         5000m
# 2106  2006  Turin      Skiing  Cross Country S  CAN  Sprint 1.5km
# 2108  2006  Turin      Skiing   Freestyle Ski.  CAN        moguls
#
#      Event gender Medal
# 2087            M  Gold
# 2090            M  Gold
# 2092            W  Gold
# 2099            W  Gold
# 2103            W  Gold
# 2106            W  Gold
# 2108            W  Gold

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data[(data['NOC']=='CAN')&(data['Medal'].count())]
# Out:
#       Year         City       Sport       Discipline  NOC            Event  \
# 4     1924     Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# 54    1928   St. Moritz  Ice Hockey       Ice Hockey  CAN       ice hockey
# 92    1932  Lake Placid  Ice Hockey       Ice Hockey  CAN       ice hockey
# 93    1932  Lake Placid     Skating   Figure skating  CAN       individual
# 94    1932  Lake Placid     Skating    Speed skating  CAN           10000m
# ...    ...          ...         ...              ...  ...              ...
# 2105  2006        Turin     Skating    Speed skating  CAN     Team pursuit
# 2106  2006        Turin      Skiing  Cross Country S  CAN     Sprint 1.5km
# 2107  2006        Turin      Skiing  Cross Country S  CAN      Team sprint
# 2108  2006        Turin      Skiing   Freestyle Ski.  CAN           moguls
# 2109  2006        Turin      Skiing        Snowboard  CAN  Snowboard Cross
#
#      Event gender   Medal
# 4               M    Gold
# ...

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data[data['NOC']== 'CAN'] #lấy dữ liệu nước canada
data['Medal'].value_counts()   #đếm số huy chương vàng bạc đồng trong cột huy chương của toàn bộ  dữ liệu
# Out:
# Gold      774
# Silver    773
# Bronze    764
# Name: Medal, dtype: int64

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.groupby((data['NOC']=='CAN')&(data['Year']==2006)&(data['Medal']=='Gold')).count()      #đếm số huy chương vàng năm 2006 của canada
# Out:
#        Year  City  Sport  Discipline   NOC  Event  Event gender  Medal
# False  2304  2304   2304        2304  2304   2304          2304   2304
# True      7     7      7           7     7      7             7      7

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.groupby((data['NOC']=='CAN')&(data['Year']==2006)&(data['Medal']=='Silver')).count()    #đếm số huy chương bạc năm 2006 của canada
# Out:
#        Year  City  Sport  Discipline   NOC  Event  Event gender  Medal
# False  2301  2301   2301        2301  2301   2301          2301   2301
# True     10    10     10          10    10     10            10     10

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.groupby((data['NOC']=='CAN')&(data['Year']==2006)&(data['Medal']=='Bronze')).count()    #đếm số huy chương đồng năm 2006 của canada
# Out:
#        Year  City  Sport  Discipline   NOC  Event  Event gender  Medal
# False  2304  2304   2304        2304  2304   2304          2304   2304
# True      7     7      7           7     7      7             7      7

# %%
import pandas as pd
url = 'http://Winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.groupby((data['NOC']=='CAN')&(data['Year']==2006)&data['Medal']).count()
# Out:
#        Year  City  Sport  Discipline   NOC  Event  Event gender  Medal
# False  2287  2287   2287        2287  2287   2287          2287   2287
# True     24    24     24          24    24     24            24     24
